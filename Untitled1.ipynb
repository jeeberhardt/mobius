# %%
# %matplotlib inline

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))

import json
import urllib3
import requests

import umap.umap_ as umap
import freesasa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.optimize as optimize
from sklearn.manifold import MDS
from MDAnalysis import Universe
from MDAnalysis.analysis import rms
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from bs4 import BeautifulSoup
from bokeh.io import output_notebook, show, export_png
from bokeh.models import HoverTool, LinearColorMapper
from bokeh.layouts import row
from bokeh.plotting import figure, ColumnDataSource, output_file, save

from mobius import VirtualTarget, ForceField

urllib3.disable_warnings()
output_notebook()

import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# <style>.container { width:70% !important; }</style>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1106">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Rosetta MHC dataset

# %%
url = 'https://rosettamhc.chemistry.ucsc.edu'
json_url = 'https://rosettamhc.chemistry.ucsc.edu/static/%s.json'
pdb_url = 'https://rosettamhc.chemistry.ucsc.edu/static/%s-ensemble.pdb'

# %%
http = urllib3.PoolManager(cert_reqs = 'CERT_NONE')
resp = http.request("GET", url=url)
soup = BeautifulSoup(resp.data, 'html.parser')
peptides = [o.text for o in soup.find_all('option')[1:]]

# %%
! mkdir 'data'
! mkdir 'data/rosetta_mhc'
! mkdir 'data/rosetta_mhc/pdb'

# %%
data = []

for peptide in peptides:
    print(peptide)

    # Download PDB file
    resp = http.request("GET", url=pdb_url % peptide)
    with open('data/rosetta_mhc/pdb/%s-ensemble.pdb' % peptide, 'w') as w:
        w.write(resp.data.decode("utf-8"))

    # Get JSON file
    resp = http.request("GET", url=json_url % peptide)
    json_data = json.loads(resp.data)

    data.append((peptide, len(peptide), float(json_data['ba']),
                 float(json_data['energy']), json_data['template']))

columns = ['peptide', 'length', 'binding_affinity', 'energy', 'template']
df = pd.DataFrame(data=data, columns=columns)
df.to_csv('data/rosetta_mhc/peptide_binding_affinity.csv', index=False)
# Out:
# AALLADKFPV
# ADLDDFSKQL
# AFLPFAMGI
# AIASEFSSL
# AIFYLITPV
# AIMTRCLAV
# AINRPQIGV
# AIPTNFTISV
# ALAPNMMV
# ALAPNMMVT
# ALCADSIII
# ALDISASIV
# ALFAYTKRNV
# ALGGSVAIKI
# ALGKLQDVV
# ALGVLMSNL
# ALITLATCEL
# ALLADKFPV
# ALLADKFPVL
# ALLAGTITS
# ALLAVFQSA
# ALLEDEFTPF
# ALLEDEFTP
# ALLSDLQDL
# ALLTLQQIEL
# ALNKATNNA
# ALNLGETFV
# ALNNIINNA
# ALNTLVKQL
# ALPETTADI
# ALPETTADIV
# ALQDAYYRA
# ALQIPFAMQM
# ALRANSAVKL
# ALSKGVHFV
# ALVSDVGDSA
# ALVYDNKLKA
# ALVYFLQSI
# ALWEIQQV
# ALWEIQQVV
# ALYYPSARI
# ALYYPSARIV
# AMGIIAMSA
# AMQTMLFTM
# AMRNAGIVGV
# AMSAFAMMFV
# AMYTPHTV
# AMYTPHTVL
# AQFAPSASA
# AQVDVVNFNL
# ASFDNFKFV
# ASLPFGWLI
# ATIPIQASL
# ATVAYFNMV
# AVANGDSEV
# AVASKILGL
# AVIKTLQPV
# AVINGDRWFL
# AVLDMCASL
# DLFMRIFTI
# DLNETLVTM
# ELDERIDKV
# ELFENKTTL
# ELLHAPATV
# ELTPVVQTI
# ELYSPIFLI
# ELYSPIFLIV
# FAFACPDGV
# FAQDGNAAI
# FCLEASFNYL
# FCNDPFLGV
# FDMSKFPLKL
# FELDERIDKV
# FELLHAPATV
# FFFYENAFL
# FGADPIHSL
# FGDDTVIEV
# FGMSRIGMEV
# FHLDGEVITF
# FHLVDFQVTI
# FIAGLIAIV
# FIASFRLFA
# FIEDLLFNKV
# FIRQEEVQEL
# FISDEVARDL
# FITESKPSV
# FKLNEEIAII
# FKLSYGIATV
# FKLVNKFLAL
# FLAFVVFL
# FLAFVVFLL
# FLAHIQWMV
# FLALCADSI
# FLALITLA
# FLALITLAT
# FLARGIVFM
# FLEGETLPT
# FLELAMDEFI
# FLEMKSEKQV
# FLEYHDVRV
# FLEYHDVRVV
# FLFVAAIFYL
# FLGIITTVA
# FLGIITTV
# FLGRYMSAL
# FLHFLPRV
# FLHVTYVPA
# FLIGCNYL
# FLIVAAIVFI
# FLKKDAPYI
# FLKKDAPYIV
# FLKRGDKSV
# FLLNKEMYL
# FLLPSLATVA
# FLLPSLATV
# FLLVTLAIL
# FLMSFTVLC
# FLMSFTVLCL
# FLMSFTVL
# FLNGSCGSV
# FLNKVVSTT
# FLNRFTTTL
# FLPFAMGI
# FLPFFSNV
# FLPGVYSVI
# FLPGVYSV
# FLPRVFSA
# FLPRVFSAV
# FLQSINFV
# FLQSINFVRI
# FLRDGWEI
# FLRDGWEIV
# FLTENLLL
# FLTENLLLYI
# FLTENLLLY
# FLVFLGIITT
# FLVLLPLV
# FLVQAGNVQL
# FLWLLWPV
# FLWLLWPVTL
# FPLNSIIKTI
# FQFCNDPFL
# FQSASKIITL
# FSASTSAFV
# FSYFAVHFI
# FTISVTTEI
# FVAAIFYLI
# FVCDNIKFA
# FVDGVPFV
# FVDGVPFVV
# FVDRQTAQA
# FVENPDILRV
# FVFPLNSII
# FVLAAVYRI
# FVLWAHGFEL
# FVMMSAPPA
# FVNEFYAYL
# FVSDADSTL
# FVSEETGTL
# FVSNGTHWFV
# FVTVYSHLL
# FVVPGLPGTI
# FVVPGLPGT
# FYLITPVHVM
# FYLTNDVSFL
# GALDISASI
# GDISGINASV
# GINASVVNI
# GISQYSLRL
# GKIADYNYKL
# GLAAIMQLF
# GLAAIMQL
# GLALYYPSA
# GLCVDIPGI
# GLEAPFLYL
# GLFKDCSKV
# GLIAIVMV
# GLIAIVMVTI
# GLIAIVMVT
# GLLPPKNSI
# GLMWLSYFI
# GLNDNLLEI
# GLNDNLLEIL
# GLNGYTVEEA
# GLPGTILRT
# GLPWNVVRI
# GLTVLPPLL
# GLVAEWFLA
# GLVEVEKGV
# GLVEVEKGVL
# GLWLDDVV
# GLWLDDVVYC
# GLYPTLNI
# GLYPTLNIS
# GMSRIGMEV
# GMVLGSLAA
# GNLHPDSATL
# GQINDMILSL
# GQQFGPTYL
# GRLQSLQTYV
# GVAPGTAVL
# GVDIAANTV
# GVFCGVDAV
# GVGYQPYRV
# GVVTTVMFL
# GVYDYLVST
# GVYSVIYLYL
# GWLIVGVALL
# GYLNSTNVTI
# HLDGEVITF
# HLIPLMYKGL
# HLKDGTCGL
# HLLLVAAGL
# HLMSFPQSA
# HLVDFQVTIA
# HLVDFQVTI
# HMLDMYSV
# HMLDMYSVM
# HMLDMYSVML
# HPLADNKFAL
# HTIDGSSGV
# HVMVELVAEL
# HVVAFNTLL
# IAIPTNFTI
# IFFASFYYV
# IFVDGVPFV
# IFVDGVPFVV
# IIFLEGETL
# IIQFPNTYL
# IITTDNTFV
# IIWFLLLSV
# ILANTCTERL
# ILASFSAST
# ILAYCNKTV
# ILDGISQYS
# ILDGISQYSL
# ILFLALITL
# ILFTRFFYV
# ILGLPTQTV
# ILGPLSAQT
# ILGTVSWNL
# ILHCANFNV
# ILKPANNSL
# ILLAKDTTEA
# ILLLDQALV
# ILLNKHIDA
# ILNNLGVDI
# ILQKEKVNI
# ILSDDAVVC
# ILSDDAVV
# ILSPLYAFA
# ILTSLLVLV
# INVFAFPFTI
# IQPGQTFSV
# ISDEFSSNV
# ISMDNSPNL
# ISMWALIISV
# ITFDNLKTL
# IVAGGIVAI
# IVAGGIVAIV
# IVDEPEEHV
# IVDTVSALV
# IVGDVVQEGV
# IVGVALLAV
# IVNSVLLFL
# KALNLGETFV
# KIADYNYKL
# KIAEIPKEEV
# KIFVDGVPFV
# KIILFLALI
# KILGLPTQTV
# KITEHSWNA
# KIVDEPEEHV
# KIYSKHTPI
# KKLLEQWNLV
# KLALGGSVAI
# KLDDKDPNF
# KLDGFMGRI
# KLDGVVCTEI
# KLDNDALNNI
# KLFAAETL
# KLFAAETLKA
# KLFDRYFKY
# KLFIRQEEV
# KLGSLVVRC
# KLHDELTGHM
# KLIEYTDFA
# KLIEYTDFAT
# KLINIIIWF
# KLINIIIWFL
# KLKDCVMYA
# KLKPVLDWL
# KLKTLVATA
# KLLEQWNL
# KLLEQWNLVI
# KLLEQWNLV
# KLLKSIAAT
# KLMPVCVET
# KLNDLCFTNV
# KLNEEIAII
# KLNEEIAIIL
# KLNEEIAI
# KLNIKLLGV
# KLNVGDYFV
# KLNVGDYFVL
# KLPDDFTGC
# KLPDDFTGCV
# KLQDVVNQNA
# KLQFTSLEI
# KLQNNELSPV
# KLRGTAVMSL
# KLRSDVLLPL
# KLSHQSDIEV
# KLSYGIATV
# KLTDNVYI
# KLVLSVNPYV
# KLVNKFLAL
# KLVSSFLEM
# KLWAQCVQL
# KMADQAMTQM
# KMAFPSGKV
# KMFDAYVNTF
# KMFDAYVNT
# KMSDVKCTSV
# KMVSLLSVL
# KNLNESLIDL
# KNLSDRVVFV
# KNLYDKLVSS
# KQGDDYVYL
# KQIYKTPPI
# KQLIKVTLV
# KQVVSDIDYV
# KTIGPDMFL
# KTLQPVSELL
# KVAGFAKFL
# KVDGVDVEL
# KVDGVVQQL
# KVEGCMVQV
# KVFTTVDNI
# LALSKGVHFV
# LAWPLIVTA
# LIIMRTFKV
# LIVAAIVFI
# LLADKFPV
# LLADKFPVL
# LLAKDTTEA
# LLALHRSYL
# LLAPLLSAGI
# LLDDFVEII
# LLDDFVEI
# LLDQALVSDV
# LLEQWNLVI
# LLESELVIGA
# LLFLMSFTV
# LLFNKVTLA
# LLFNKVTL
# LLHKPIVWHV
# LLIVNNATNV
# LLLDDFVEII
# LLLDDFVEI
# LLLDQALV
# LLLDRLNQL
# LLLLDRLNQL
# LLLTILTSL
# LLMPILTL
# LLMPILTLT
# LLPSLATV
# LLSAGIFGA
# LLTILTSLL
# LLTLQQIEL
# LLTNMFTPL
# LLTPLGIDL
# LLVAAGLEA
# LLWPVTLAC
# LLYDANYFL
# LLYIDINGNL
# LMCQPILLL
# LMDGSIIQF
# LMIERFVSL
# LMWLIINLV
# LMYKGLPWNV
# LQAENVTGL
# LQAGNATEV
# LQIPFAMQM
# LQLGFSTGV
# LQNNELSPV
# LVFLGIITTV
# LVLSVNPYV
# LVSDIDITFL
# LWAHGFEL
# LYDANYFL
# MELTPVVQTI
# MIAQYTSAL
# MILSDDAVV
# MLAKALRKV
# MLDMYSVML
# MLFTMLRKL
# MLNPNYEDL
# MLNPNYEDLL
# MLSDTLKNL
# MLVKQGDDYV
# MLWCKDGHV
# MMILSDDAV
# MMISAGFSL
# MMVTNNTFTL
# MQVESDDYI
# MVLGSLAATV
# MVMCGGSLYV
# MVTNNTFTL
# MVYMPASWV
# NDLNETLVTM
# NLACEDLKPV
# NLAKHCLHV
# NLAWPLIVTA
# NLAWPLIVT
# NLDYIINLI
# NLDYIINL
# NLHPDSATL
# NLHPDSATLV
# NLIDSYFV
# NLIDSYFVV
# NLLKDCPAV
# NLLLLFVTV
# NLNESLIDL
# NLREMLAHA
# NLSDRVVFV
# NLSDRVVFVL
# NLVAVPTGYV
# NLVIGFLFL
# NLWNTFTRL
# NLYDKLVSS
# NMFTPLIQPI
# NMLRIMASL
# NMMISAGFSL
# NTFSSTFNV
# NTLNDLNETL
# NTQEVFAQV
# NVFAFPFTI
# NVLAWLYAA
# NVLTLVYKV
# NVYADSFVI
# PLADNKFAL
# PLVDLPIGI
# PVYSFLPGV
# QELYSPIFLI
# QIDGYVMHA
# QINDMILSL
# QLCQYLNTL
# QLDEEQPMEI
# QLEMELTPV
# QLEMELTPVV
# QLFFSYFAV
# QLGFSTGVNL
# QLGGLHLLI
# QLHNDILLA
# QLLFVVEVV
# QLMCQPILL
# QLMCQPILLL
# QLNRALTGI
# QLSLPVLQV
# QMAPISAMV
# QMEIDFLELA
# QQGEVPVSI
# QVDVVNFNL
# QVVSDIDYV
# RAMPNMLRI
# RDLYDKLQFT
# RIDGDMVPHI
# RIFTIGTVTL
# RIIPARARV
# RILGAGCFV
# RIMASLVLA
# RIMTWLDMV
# RIQPGQTFSV
# RITGLYPTL
# RLANECAQV
# RLDKVEAEV
# RLFARTRSM
# RLIDAMMFT
# RLIDAMMFTS
# RLITGRLQSL
# RLNEVAKNL
# RLQAGNATEV
# RLQSLQTYV
# RLSFKELLV
# RLTLGVYDYL
# RLYLDAYNM
# RLYLDAYNMM
# RPLLESELVI
# RQLLFVVEV
# RSLPGVFCGV
# RTIKVFTTV
# RVWTLMNVL
# RVYSTGSNV
# SALWEIQQVV
# SFLAHIQWMV
# SFLPGVYSV
# SIAIPTNFTI
# SIDAFKLNI
# SIIAYTMSL
# SIIKTIQPRV
# SIIQFPNTYL
# SIVAGGIVAI
# SIWNLDYII
# SKLIEYTDFA
# SLAIDAYPL
# SLAIDAYPLT
# SLDNVLSTFI
# SLDNVLSTF
# SLDTYPSL
# SLENVAFNV
# SLENVAFNVV
# SLETIQITI
# SLFDMSKFPL
# SLIDLQEL
# SLINTLNDL
# SLIYSTAAL
# SLKVPATVSV
# SLLMPILTL
# SLLMPILTLT
# SLLSVLLSM
# SLPFGWLIV
# SLPGVFCGV
# SLPSYAAFA
# SLQTYVTQQL
# SLREVRTIKV
# SLRPDTRYV
# SLSHRFYRL
# SLSSTASAL
# SLVKPSFYV
# SMATNYDLSV
# SMDNSPNLA
# SMQNCVLKL
# SMSYEDQDAL
# SMWALIISV
# SMWSFNPET
# SQLGGLHLLI
# SQLGGLHLL
# SQLMCQPILL
# SQMEIDFLEL
# SRLDKVEAEV
# STDTGVEHV
# STLIGDCATV
# STSAFVETV
# SVAALTNNV
# SVFNICQAV
# SVLLFLAFV
# SVLNDILSRL
# SVLYYQNNV
# SVTTEILPV
# SVVSKVVKV
# SWLMWLIINL
# TIAEILLII
# TIVEVQPQL
# TLACFVLAA
# TLACFVLAAV
# TLATHGLAA
# TLATHGLAAV
# TLAVPYNMRV
# TLDSKTQSL
# TLEPEYFNSV
# TLETAQNSV
# TLGVLVPHV
# TLGVYDYLV
# TLIGDCATV
# TLIGEAVKT
# TLIVNSVLL
# TLKNTVCTV
# TLMIERFVSL
# TLMNVLTL
# TLMNVLTLV
# TLNDFNLVA
# TLNDFNLVAM
# TLNDFNLV
# TLNDLNETL
# TLNDLNETLV
# TLPKGIMMNV
# TLPVNVAFEL
# TLQAENVTGL
# TLQPVSELL
# TLSEQLDFI
# TLVPQEHYV
# TLVSDIDITF
# TLVTMPLGYV
# TMADLVYAL
# TMCDIRQLL
# TPVYSFLPGV
# TQAPTHLSV
# TQYNRYLAL
# TTIQTIVEV
# TTLKGVEAV
# TTLNDFNLVA
# TVASLINTL
# TVYDPLQPEL
# TVYEKLKPV
# TVYSHLLLV
# TVYTKVDGV
# TWLDMVDTSL
# VELFENKTTL
# VFLGIITTV
# VIGIVNNTV
# VINGDRWFL
# VLAWLYAAV
# VLCNSQTSL
# VLGLAAIMQL
# VLGSLAATV
# VLHDIGNPKA
# VLHSTQDLFL
# VLLAPLLSA
# VLLFLAFVV
# VLLSMQGAV
# VLLSVLQQL
# VLMDGSII
# VLMDGSIIQF
# VLNDILSRL
# VLNNDYYRSL
# VLPNDDTLRV
# VLPQLEQPYV
# VLQAVGACV
# VLQKAAITI
# VLQLPQGTTL
# VLQVRDVLV
# VLSDRELHL
# VLSEARQHL
# VLSFCAFAV
# VLSFELLHA
# VLSTFISAA
# VLSVNPYV
# VLVPHVGEI
# VLVRGFGDSV
# VLWAHGFEL
# VLYENQKLIA
# VLYENQKLI
# VLYQPPQTSI
# VLYYQNNVFM
# VMAYITGGV
# VMCGGSLYV
# VMPLSAPTL
# VMPLSAPTLV
# VMVELVAEL
# VMYASAVVL
# VMYASAVVLL
# VQEGVLTAV
# VQLHNDILLA
# VQLHNDILL
# VQLSLPVLQV
# VQMAPISAM
# VQMAPISAMV
# VSLVKPSFYV
# VTIAEILLI
# VTWFHAIHV
# VVADAVIKTL
# VVDSYYSLL
# VVFDEISMA
# VVFLHVTYV
# VVIGIVNNTV
# VVISSDVLV
# VVLLSVLQQL
# VVMAYITGGV
# VVNAANVYL
# VVNPVMEPI
# VVQEGVLTA
# VVQEGVLTAV
# WLDDDSQQT
# WLDDDSQQTV
# WLDMVDTSL
# WLIINLVQM
# WLIVGVALL
# WLLWPVTLA
# WLMWLIINL
# WLPTGTLLV
# WLTNIFGTV
# WLTYTGAIKL
# WMVMFTPLV
# WTLMNVLTLV
# YADVFHLYL
# YDLSVVNARL
# YFLQSINFV
# YHLMSFPQSA
# YIATNGPLKV
# YIDIGNYTV
# YIFFASFYYV
# YIINLIIKNL
# YILFTRFFYV
# YITGGVVQL
# YIVDSVTV
# YIWLGFIAGL
# YKLNVGDYFV
# YLASGGQPI
# YLATALLTL
# YLAVFDKNL
# YLDAYNMMI
# YLDAYNMM
# YLDGADVTKI
# YLEGSVRV
# YLEGSVRVV
# YLFDESGEF
# YLFQHANL
# YLGGMSYYC
# YLGKPREQI
# YLGTGPEAGL
# YLITPVHV
# YLITPVHVM
# YLKLRSDVLL
# YLKLTDNVYI
# YLKSPNFSKL
# YLNSTNVTIA
# YLNSTNVTI
# YLNTLTLAV
# YLPQNAVVKI
# YLPYPDPSRI
# YLQPRTFL
# YLQPRTFLL
# YLTFYLTNDV
# YLTNDVSFLA
# YLTNDVSFL
# YLVQQESPFV
# YLYALVYFL
# YLYFIKGL
# YLYLTFYL
# YLYLTFYLT
# YMPASWVMRI
# YMPYFFTL
# YMPYFFTLL
# YNLLKDCPAV
# YNLWNTFTRL
# YPIIGDELKI
# YQDVNCTEV
# YQHEETIYNL
# YQVNGYPNM
# YRLANECAQV
# YRLYLDAYNM
# YSFLPGVYSV
# YSLLMPILTL
# YTMADLVYA
# YTMADLVYAL
# YTNSFTRGV
# YTVEEAKTV
# YTVELGTEV
# YVDNSSLTI
# YVFCTVNAL
# YVLPNDDTL
# YVVDDPCPI
# YVWKSYVHV
# YVWKSYVHVV
# YVYIGDPAQL
# YVYNPFMIDV
# YVYSRVKNL
# YYLFDESGEF

# %%
df = pd.read_csv('data/rosetta_mhc/peptide_binding_affinity.csv')

# %% [markdown]
# ## Correlation using all MHC structures

# %%
peptides_selection = df[df['length'] == 9].sort_values(by='binding_affinity')

solvent_exposure = []

for peptide in peptides_selection.itertuples():
    print(peptide.peptide)

    structure = freesasa.Structure('data/rosetta_mhc/pdb/%s-ensemble.pdb' % peptide.peptide)
    result = freesasa.calc(structure)
    
    surface_contact = [result.residueAreas()['A']['%s' % i].relativeSideChain for i in range(181, 190)]
    solvent_exposure.append(surface_contact)

solvent_exposure = np.array(solvent_exposure)
solvent_exposure = np.nan_to_num(solvent_exposure, nan=0)
# Out:
# FLAHIQWMV
# ILFTRFFYV
# FLLPSLATV
# YLYALVYFL
# LLYDANYFL
# FLLNKEMYL
# YLDAYNMMI
# TMADLVYAL
# TLMNVLTLV
# YLQPRTFLL
# YLNTLTLAV
# GLMWLSYFI
# SMWALIISV
# LLLDDFVEI
# FLARGIVFM
# FVNEFYAYL
# NLIDSYFVV
# ALLADKFPV
# VLWAHGFEL
# FLPRVFSAV
# FLNRFTTTL
# KLIEYTDFA
# KLLEQWNLV
# FLAFVVFLL
# RIMTWLDMV
# LMIERFVSL
# MMISAGFSL
# YLATALLTL
# QLFFSYFAV
# YLTNDVSFL
# ILTSLLVLV
# YTMADLVYA
# ALWEIQQVV
# VLAWLYAAV
# MLDMYSVML
# VLSFCAFAV
# FIAGLIAIV
# SLVKPSFYV
# LLFLMSFTV
# KLNVGDYFV
# ILHCANFNV
# ALSKGVHFV
# YIDIGNYTV
# FQFCNDPFL
# WMVMFTPLV
# FLGRYMSAL
# FVAAIFYLI
# KLSYGIATV
# SLPGVFCGV
# NLSDRVVFV
# VMVELVAEL
# FVLAAVYRI
# LLADKFPVL
# YMPYFFTLL
# AIFYLITPV
# LLLDRLNQL
# FVDGVPFVV
# GLNDNLLEI
# YLASGGQPI
# KLWAQCVQL
# ILSPLYAFA
# YVWKSYVHV
# QLMCQPILL
# NVFAFPFTI
# QMAPISAMV
# WLMWLIINL
# TLIGDCATV
# FLALCADSI
# RLIDAMMFT
# VMCGGSLYV
# TLVPQEHYV
# KIADYNYKL
# LLMPILTLT
# TVYSHLLLV
# FVMMSAPPA
# LLLTILTSL
# SIIAYTMSL
# FLKKDAPYI
# VLNDILSRL
# LLFNKVTLA
# FLNGSCGSV
# AVIKTLQPV
# ILGTVSWNL
# LQLGFSTGV
# YLNSTNVTI
# LLSAGIFGA
# RQLLFVVEV
# RLQSLQTYV
# HLVDFQVTI
# NVLAWLYAA
# LVLSVNPYV
# TLGVYDYLV
# VVFLHVTYV
# SQLGGLHLL
# NLLKDCPAV
# ILLLDQALV
# RLANECAQV
# FLEYHDVRV
# TLSEQLDFI
# VLLSVLQQL
# FLLVTLAIL
# TLGVLVPHV
# ALVYFLQSI
# WLDMVDTSL
# YLITPVHVM
# MLWCKDGHV
# LLTNMFTPL
# TLACFVLAA
# VMAYITGGV
# VLLFLAFVV
# SLLSVLLSM
# GVFCGVDAV
# KLFIRQEEV
# KLVNKFLAL
# SMWSFNPET
# SVLLFLAFV
# WLPTGTLLV
# FLHVTYVPA
# LLDDFVEII
# WLIVGVALL
# YLYLTFYLT
# WLTNIFGTV
# KLNEEIAII
# MMILSDDAV
# KLMPVCVET
# TLNDLNETL
# IIWFLLLSV
# YVFCTVNAL
# KLKDCVMYA
# FLPGVYSVI
# SLENVAFNV
# SLAIDAYPL
# ALLAVFQSA
# GLVAEWFLA
# MLAKALRKV
# FLRDGWEIV
# HLMSFPQSA
# AIMTRCLAV
# WLLWPVTLA
# AMQTMLFTM
# RIMASLVLA
# RLDKVEAEV
# ALNLGETFV
# TVYEKLKPV
# GMSRIGMEV
# KMFDAYVNT
# FTISVTTEI
# FLALITLAT
# KLNIKLLGV
# FIASFRLFA
# VLGSLAATV
# FAFACPDGV
# MLSDTLKNL
# VLLAPLLSA
# KMVSLLSVL
# FLMSFTVLC
# NLWNTFTRL
# SLPSYAAFA
# NLLLLFVTV
# YLAVFDKNL
# LIIMRTFKV
# RILGAGCFV
# VLSTFISAA
# YVVDDPCPI
# GLFKDCSKV
# FSASTSAFV
# GVYDYLVST
# YITGGVVQL
# ILAYCNKTV
# LMWLIINLV
# GLALYYPSA
# QLLFVVEVV
# SIWNLDYII
# SLIYSTAAL
# FITESKPSV
# MLFTMLRKL
# LLTILTSLL
# FSYFAVHFI
# ALQDAYYRA
# NTFSSTFNV
# SMQNCVLKL
# NMLRIMASL
# YQDVNCTEV
# FLNKVVSTT
# IVDTVSALV
# ALLSDLQDL
# SLLMPILTL
# VLSDRELHL
# ILFLALITL
# MIAQYTSAL
# IFFASFYYV
# KQIYKTPPI
# IVAGGIVAI
# TLQPVSELL
# SLSHRFYRL
# KLVSSFLEM
# SVFNICQAV
# FVTVYSHLL
# FLGIITTVA
# NLAKHCLHV
# KIILFLALI
# LQNNELSPV
# ILGLPTQTV
# KLKPVLDWL
# ELYSPIFLI
# YLGGMSYYC
# VMYASAVVL
# VLLSMQGAV
# YTVELGTEV
# SLINTLNDL
# NVLTLVYKV
# RLSFKELLV
# GLTVLPPLL
# VLQAVGACV
# TLNDFNLVA
# ILASFSAST
# LMCQPILLL
# IQPGQTFSV
# VTWFHAIHV
# IVNSVLLFL
# ATVAYFNMV
# LQAENVTGL
# NLDYIINLI
# HLLLVAAGL
# GLEAPFLYL
# GLVEVEKGV
# NLYDKLVSS
# GLCVDIPGI
# ALNNIINNA
# NLNESLIDL
# SVTTEILPV
# KLQFTSLEI
# IFVDGVPFV
# LIVAAIVFI
# VLSFELLHA
# YLFDESGEF
# RTIKVFTTV
# KLDGFMGRI
# VLVPHVGEI
# KLLKSIAAT
# STSAFVETV
# TLIVNSVLL
# FVSDADSTL
# SVAALTNNV
# TIAEILLII
# MVTNNTFTL
# LLTLQQIEL
# RLYLDAYNM
# YADVFHLYL
# MILSDDAVV
# FVFPLNSII
# KITEHSWNA
# QLGGLHLLI
# QLEMELTPV
# LLTPLGIDL
# FVVPGLPGT
# AVLDMCASL
# YVDNSSLTI
# MLNPNYEDL
# LLAKDTTEA
# PVYSFLPGV
# TLDSKTQSL
# KQLIKVTLV
# MVYMPASWV
# WLIINLVQM
# TMCDIRQLL
# TVYTKVDGV
# LLWPVTLAC
# SLPFGWLIV
# MQVESDDYI
# QLSLPVLQV
# KIYSKHTPI
# LLALHRSYL
# FLEGETLPT
# KMAFPSGKV
# SFLPGVYSV
# GLIAIVMVT
# VLSEARQHL
# QVVSDIDYV
# RLNEVAKNL
# HMLDMYSVM
# FVSEETGTL
# VLQVRDVLV
# NLVIGFLFL
# KQGDDYVYL
# FFFYENAFL
# SVVSKVVKV
# GVVTTVMFL
# ILNNLGVDI
# IITTDNTFV
# YVLPNDDTL
# YFLQSINFV
# IVGVALLAV
# FGDDTVIEV
# YLEGSVRVV
# TLKNTVCTV
# SLETIQITI
# YQVNGYPNM
# ASLPFGWLI
# VLYENQKLI
# SVLYYQNNV
# LQAGNATEV
# ALPETTADI
# AIASEFSSL
# QLCQYLNTL
# QINDMILSL
# VLQKAAITI
# ALYYPSARI
# NVYADSFVI
# TTIQTIVEV
# GLPWNVVRI
# HTIDGSSGV
# ALGVLMSNL
# VQMAPISAM
# LLEQWNLVI
# VVFDEISMA
# LLVAAGLEA
# QLNRALTGI
# DLFMRIFTI
# FVCDNIKFA
# VINGDRWFL
# VVISSDVLV
# SLRPDTRYV
# YTNSFTRGV
# ASFDNFKFV
# KVDGVDVEL
# NLAWPLIVT
# KLPDDFTGC
# VVNPVMEPI
# ALDISASIV
# AMYTPHTVL
# ELLHAPATV
# ALCADSIII
# KVEGCMVQV
# ALAPNMMVT
# AVASKILGL
# RVWTLMNVL
# KTIGPDMFL
# NLHPDSATL
# QLHNDILLA
# VVNAANVYL
# VMPLSAPTL
# ILGPLSAQT
# RLFARTRSM
# TIVEVQPQL
# HVVAFNTLL
# KLKTLVATA
# RITGLYPTL
# LAWPLIVTA
# GMVLGSLAA
# VTIAEILLI
# ILKPANNSL
# ISDEFSSNV
# AMGIIAMSA
# VQLHNDILL
# TQYNRYLAL
# NTQEVFAQV
# SIDAFKLNI
# ILLNKHIDA
# SLSSTASAL
# VQEGVLTAV
# LQIPFAMQM
# NLREMLAHA
# VVDSYYSLL
# KVDGVVQQL
# TQAPTHLSV
# FCNDPFLGV
# ALNTLVKQL
# VLCNSQTSL
# YVYSRVKNL
# TTLKGVEAV
# ALLAGTITS
# IIQFPNTYL
# HLKDGTCGL
# ALGKLQDVV
# KLINIIIWF
# AQFAPSASA
# YLGKPREQI
# GLLPPKNSI
# KVAGFAKFL
# KVFTTVDNI
# LMDGSIIQF
# IAIPTNFTI
# VIGIVNNTV
# GINASVVNI
# FLKRGDKSV
# PLVDLPIGI
# IVDEPEEHV
# ILDGISQYS
# FLTENLLLY
# TLATHGLAA
# FAQDGNAAI
# TVASLINTL
# KLGSLVVRC
# ILQKEKVNI
# RVYSTGSNV
# GLAAIMQLF
# ISMDNSPNL
# IIFLEGETL
# RIIPARARV
# YTVEEAKTV
# FGADPIHSL
# QVDVVNFNL
# RAMPNMLRI
# AFLPFAMGI
# ATIPIQASL
# ILSDDAVVC
# VFLGIITTV
# SMDNSPNLA
# TLETAQNSV
# FVDRQTAQA
# GVAPGTAVL
# ELDERIDKV
# KLDDKDPNF
# QIDGYVMHA
# PLADNKFAL
# AVANGDSEV
# KLFDRYFKY
# ALNKATNNA
# GALDISASI
# GQQFGPTYL
# SLDNVLSTF
# VVQEGVLTA
# GLYPTLNIS
# AINRPQIGV
# ITFDNLKTL
# ALLEDEFTP
# WLDDDSQQT
# GISQYSLRL
# TLIGEAVKT
# ELFENKTTL
# GLPGTILRT
# HLDGEVITF
# QQGEVPVSI
# STDTGVEHV
# GVGYQPYRV
# ELTPVVQTI
# GVDIAANTV
# DLNETLVTM

# %%
np.mean(solvent_exposure, axis=0)
# Out:
# array([0.16251919, 0.00954017, 0.04687939, 0.61385485, 0.38845837,
#        0.22441687, 0.24580333, 0.4980927 , 0.00279104])

# %%
np.std(solvent_exposure, axis=0)
# Out:
# array([0.111617  , 0.01278511, 0.07221377, 0.24834302, 0.26640823,
#        0.24830759, 0.16256755, 0.15354441, 0.00750467])

# %%
ff = ForceField('mobius/data/parameters.csv')
ff._term_parameters['vdw']['score_max'] = 2
ff._term_parameters['vdw']['smooth'] = 0.2
ff._term_parameters['vdw']['n'] = 4
print(ff._term_parameters)

vt = VirtualTarget(ff)
# Out:
# {'vdw': {'epsilon': 1, 'smooth': 0.2, 'score_max': 2, 'n': 4, 'm': 3}}

# %%
target_sequence = peptides_selection.iloc[0]['peptide']
vt.generate_pharmacophore_from_target_sequence(target_sequence, solvent_exposures=solvent_exposure[0])

# %%
scores = vt.score_peptides(peptides_selection['peptide'], noise=0)
terms = np.array([ff.score(vt.pharmacophore(), p, details=True)[1] for p in peptides_selection['peptide']])

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.regplot(x=peptides_selection['binding_affinity'], y=scores, ax=ax)
ax.plot()
# Out:
# []

# %%
def fun(x, binding_affinity, terms):
    scores = np.sum(np.prod((terms, x), axis=0), axis=1)
    return mean_squared_error(binding_affinity, scores)

bnds = ((1, 1000), (1, 1000), (1, 1000), (1, 1000))
res = optimize.minimize(fun, (1, 1, 1, 1), method='SLSQP', args=(peptides_selection['binding_affinity'], terms), bounds=bnds, tol=1e-10)
print('vdW: %f - Electrostatic: %f - HBond: %f - Desolvation: %f' % (res.x[0], res.x[1], res.x[2], res.x[3]))

fig, ax = plt.subplots(figsize=(10, 10))
sns.regplot(x=peptides_selection['binding_affinity'], y=np.sum(np.prod((terms, res.x), axis=0), axis=1), ax=ax)
plt.plot()
# Out:
# vdW: 20.255967 - Electrostatic: 93.166525 - HBond: 37.711614 - Desolvation: 1.000000
# []

# %% [markdown]
# ## Correlation using a subset of structures

# %%
peptides = list(peptides_selection['peptide'].values)

# Remove problematic structures
peptides.pop(peptides.index('IIQFPNTYL'))
peptides.pop(peptides.index('RITGLYPTL'))

selection_str = ' or '.join(['(resid %s and not (backbone or name H*))' % i for i in [70, 97, 116, 156, 159]])

mat = np.zeros(shape=(len(peptides), len(peptides)))

for i in range(len(peptides)):
    print(peptides[i])
    u1 = Universe('data/rosetta_mhc/pdb/%s-ensemble.pdb' % peptides[i])
    s1 = u1.select_atoms(selection_str)
    
    for j in range(i + 1, len(peptides)):
        u2 = Universe('data/rosetta_mhc/pdb/%s-ensemble.pdb' % peptides[j])
        s2 = u2.select_atoms(selection_str)
        
        try:
            mat[i, j] = rms.rmsd(s1.positions, s2.positions, superposition=True)
            mat[j, i] = mat[i, j]
        except:
            print(p1, p2)

np.savetxt('data/rosetta_mhc/mat_distance.txt', mat)
# Out:
# FLAHIQWMV
# ILFTRFFYV
# FLLPSLATV
# YLYALVYFL
# LLYDANYFL
# FLLNKEMYL
# YLDAYNMMI
# TMADLVYAL
# TLMNVLTLV
# YLQPRTFLL
# YLNTLTLAV
# GLMWLSYFI
# SMWALIISV
# LLLDDFVEI
# FLARGIVFM
# FVNEFYAYL
# NLIDSYFVV
# ALLADKFPV
# VLWAHGFEL
# FLPRVFSAV
# FLNRFTTTL
# KLIEYTDFA
# KLLEQWNLV
# FLAFVVFLL
# RIMTWLDMV
# LMIERFVSL
# MMISAGFSL
# YLATALLTL
# QLFFSYFAV
# YLTNDVSFL
# ILTSLLVLV
# YTMADLVYA
# ALWEIQQVV
# VLAWLYAAV
# MLDMYSVML
# VLSFCAFAV
# FIAGLIAIV
# SLVKPSFYV
# LLFLMSFTV
# KLNVGDYFV
# ILHCANFNV
# ALSKGVHFV
# YIDIGNYTV
# FQFCNDPFL
# WMVMFTPLV
# FLGRYMSAL
# FVAAIFYLI
# KLSYGIATV
# SLPGVFCGV
# NLSDRVVFV
# VMVELVAEL
# FVLAAVYRI
# LLADKFPVL
# YMPYFFTLL
# AIFYLITPV
# LLLDRLNQL
# FVDGVPFVV
# GLNDNLLEI
# YLASGGQPI
# KLWAQCVQL
# ILSPLYAFA
# YVWKSYVHV
# QLMCQPILL
# NVFAFPFTI
# QMAPISAMV
# WLMWLIINL
# TLIGDCATV
# FLALCADSI
# RLIDAMMFT
# VMCGGSLYV
# TLVPQEHYV
# KIADYNYKL
# LLMPILTLT
# TVYSHLLLV
# FVMMSAPPA
# LLLTILTSL
# SIIAYTMSL
# FLKKDAPYI
# VLNDILSRL
# LLFNKVTLA
# FLNGSCGSV
# AVIKTLQPV
# ILGTVSWNL
# LQLGFSTGV
# YLNSTNVTI
# LLSAGIFGA
# RQLLFVVEV
# RLQSLQTYV
# HLVDFQVTI
# NVLAWLYAA
# LVLSVNPYV
# TLGVYDYLV
# VVFLHVTYV
# SQLGGLHLL
# NLLKDCPAV
# ILLLDQALV
# RLANECAQV
# FLEYHDVRV
# TLSEQLDFI
# VLLSVLQQL
# FLLVTLAIL
# TLGVLVPHV
# ALVYFLQSI
# WLDMVDTSL
# YLITPVHVM
# MLWCKDGHV
# LLTNMFTPL
# TLACFVLAA
# VMAYITGGV
# VLLFLAFVV
# SLLSVLLSM
# GVFCGVDAV
# KLFIRQEEV
# KLVNKFLAL
# SMWSFNPET
# SVLLFLAFV
# WLPTGTLLV
# FLHVTYVPA
# LLDDFVEII
# WLIVGVALL
# YLYLTFYLT
# WLTNIFGTV
# KLNEEIAII
# MMILSDDAV
# KLMPVCVET
# TLNDLNETL
# IIWFLLLSV
# YVFCTVNAL
# KLKDCVMYA
# FLPGVYSVI
# SLENVAFNV
# SLAIDAYPL
# ALLAVFQSA
# GLVAEWFLA
# MLAKALRKV
# FLRDGWEIV
# HLMSFPQSA
# AIMTRCLAV
# WLLWPVTLA
# AMQTMLFTM
# RIMASLVLA
# RLDKVEAEV
# ALNLGETFV
# TVYEKLKPV
# GMSRIGMEV
# KMFDAYVNT
# FTISVTTEI
# FLALITLAT
# KLNIKLLGV
# FIASFRLFA
# VLGSLAATV
# FAFACPDGV
# MLSDTLKNL
# VLLAPLLSA
# KMVSLLSVL
# FLMSFTVLC
# NLWNTFTRL
# SLPSYAAFA
# NLLLLFVTV
# YLAVFDKNL
# LIIMRTFKV
# RILGAGCFV
# VLSTFISAA
# YVVDDPCPI
# GLFKDCSKV
# FSASTSAFV
# GVYDYLVST
# YITGGVVQL
# ILAYCNKTV
# LMWLIINLV
# GLALYYPSA
# QLLFVVEVV
# SIWNLDYII
# SLIYSTAAL
# FITESKPSV
# MLFTMLRKL
# LLTILTSLL
# FSYFAVHFI
# ALQDAYYRA
# NTFSSTFNV
# SMQNCVLKL
# NMLRIMASL
# YQDVNCTEV
# FLNKVVSTT
# IVDTVSALV
# ALLSDLQDL
# SLLMPILTL
# VLSDRELHL
# ILFLALITL
# MIAQYTSAL
# IFFASFYYV
# KQIYKTPPI
# IVAGGIVAI
# TLQPVSELL
# SLSHRFYRL
# KLVSSFLEM
# SVFNICQAV
# FVTVYSHLL
# FLGIITTVA
# NLAKHCLHV
# KIILFLALI
# LQNNELSPV
# ILGLPTQTV
# KLKPVLDWL
# ELYSPIFLI
# YLGGMSYYC
# VMYASAVVL
# VLLSMQGAV
# YTVELGTEV
# SLINTLNDL
# NVLTLVYKV
# RLSFKELLV
# GLTVLPPLL
# VLQAVGACV
# TLNDFNLVA
# ILASFSAST
# LMCQPILLL
# IQPGQTFSV
# VTWFHAIHV
# IVNSVLLFL
# ATVAYFNMV
# LQAENVTGL
# NLDYIINLI
# HLLLVAAGL
# GLEAPFLYL
# GLVEVEKGV
# NLYDKLVSS
# GLCVDIPGI
# ALNNIINNA
# NLNESLIDL
# SVTTEILPV
# KLQFTSLEI
# IFVDGVPFV
# LIVAAIVFI
# VLSFELLHA
# YLFDESGEF
# RTIKVFTTV
# KLDGFMGRI
# VLVPHVGEI
# KLLKSIAAT
# STSAFVETV
# TLIVNSVLL
# FVSDADSTL
# SVAALTNNV
# TIAEILLII
# MVTNNTFTL
# LLTLQQIEL
# RLYLDAYNM
# YADVFHLYL
# MILSDDAVV
# FVFPLNSII
# KITEHSWNA
# QLGGLHLLI
# QLEMELTPV
# LLTPLGIDL
# FVVPGLPGT
# AVLDMCASL
# YVDNSSLTI
# MLNPNYEDL
# LLAKDTTEA
# PVYSFLPGV
# TLDSKTQSL
# KQLIKVTLV
# MVYMPASWV
# WLIINLVQM
# TMCDIRQLL
# TVYTKVDGV
# LLWPVTLAC
# SLPFGWLIV
# MQVESDDYI
# QLSLPVLQV
# KIYSKHTPI
# LLALHRSYL
# FLEGETLPT
# KMAFPSGKV
# SFLPGVYSV
# GLIAIVMVT
# VLSEARQHL
# QVVSDIDYV
# RLNEVAKNL
# HMLDMYSVM
# FVSEETGTL
# VLQVRDVLV
# NLVIGFLFL
# KQGDDYVYL
# FFFYENAFL
# SVVSKVVKV
# GVVTTVMFL
# ILNNLGVDI
# IITTDNTFV
# YVLPNDDTL
# YFLQSINFV
# IVGVALLAV
# FGDDTVIEV
# YLEGSVRVV
# TLKNTVCTV
# SLETIQITI
# YQVNGYPNM
# ASLPFGWLI
# VLYENQKLI
# SVLYYQNNV
# LQAGNATEV
# ALPETTADI
# AIASEFSSL
# QLCQYLNTL
# QINDMILSL
# VLQKAAITI
# ALYYPSARI
# NVYADSFVI
# TTIQTIVEV
# GLPWNVVRI
# HTIDGSSGV
# ALGVLMSNL
# VQMAPISAM
# LLEQWNLVI
# VVFDEISMA
# LLVAAGLEA
# QLNRALTGI
# DLFMRIFTI
# FVCDNIKFA
# VINGDRWFL
# VVISSDVLV
# SLRPDTRYV
# YTNSFTRGV
# ASFDNFKFV
# KVDGVDVEL
# NLAWPLIVT
# KLPDDFTGC
# VVNPVMEPI
# ALDISASIV
# AMYTPHTVL
# ELLHAPATV
# ALCADSIII
# KVEGCMVQV
# ALAPNMMVT
# AVASKILGL
# RVWTLMNVL
# KTIGPDMFL
# NLHPDSATL
# QLHNDILLA
# VVNAANVYL
# VMPLSAPTL
# ILGPLSAQT
# RLFARTRSM
# TIVEVQPQL
# HVVAFNTLL
# KLKTLVATA
# LAWPLIVTA
# GMVLGSLAA
# VTIAEILLI
# ILKPANNSL
# ISDEFSSNV
# AMGIIAMSA
# VQLHNDILL
# TQYNRYLAL
# NTQEVFAQV
# SIDAFKLNI
# ILLNKHIDA
# SLSSTASAL
# VQEGVLTAV
# LQIPFAMQM
# NLREMLAHA
# VVDSYYSLL
# KVDGVVQQL
# TQAPTHLSV
# FCNDPFLGV
# ALNTLVKQL
# VLCNSQTSL
# YVYSRVKNL
# TTLKGVEAV
# ALLAGTITS
# HLKDGTCGL
# ALGKLQDVV
# KLINIIIWF
# AQFAPSASA
# YLGKPREQI
# GLLPPKNSI
# KVAGFAKFL
# KVFTTVDNI
# LMDGSIIQF
# IAIPTNFTI
# VIGIVNNTV
# GINASVVNI
# FLKRGDKSV
# PLVDLPIGI
# IVDEPEEHV
# ILDGISQYS
# FLTENLLLY
# TLATHGLAA
# FAQDGNAAI
# TVASLINTL
# KLGSLVVRC
# ILQKEKVNI
# RVYSTGSNV
# GLAAIMQLF
# ISMDNSPNL
# IIFLEGETL
# RIIPARARV
# YTVEEAKTV
# FGADPIHSL
# QVDVVNFNL
# RAMPNMLRI
# AFLPFAMGI
# ATIPIQASL
# ILSDDAVVC
# VFLGIITTV
# SMDNSPNLA
# TLETAQNSV
# FVDRQTAQA
# GVAPGTAVL
# ELDERIDKV
# KLDDKDPNF
# QIDGYVMHA
# PLADNKFAL
# AVANGDSEV
# KLFDRYFKY
# ALNKATNNA
# GALDISASI
# GQQFGPTYL
# SLDNVLSTF
# VVQEGVLTA
# GLYPTLNIS
# AINRPQIGV
# ITFDNLKTL
# ALLEDEFTP
# WLDDDSQQT
# GISQYSLRL
# TLIGEAVKT
# ELFENKTTL
# GLPGTILRT
# HLDGEVITF
# QQGEVPVSI
# STDTGVEHV
# GVGYQPYRV
# ELTPVVQTI
# GVDIAANTV
# DLNETLVTM

# %%
mat = np.loadtxt('data/rosetta_mhc/mat_distance.txt')

m = MDS(n_init=10, max_iter=1000, n_components=2, dissimilarity='precomputed', n_jobs=-1)
embedding = m.fit_transform(mat)
print(m.stress_)
# Out:
# 21814.074773040753

# %%
df_tmp = pd.DataFrame(data=embedding, columns=['x', 'y'])
df_tmp['peptide'] = list(peptides_selection['peptide'].values)
df_tmp.to_csv('data/rosetta_mhc/embedding_mds.csv', index=False)

# %%
color_mapper = LinearColorMapper(palette='Viridis256', low=np.min(scores), high=10)

source = ColumnDataSource(data=dict(x=embedding[:,0], y=embedding[:,1], desc=peptides))

hover = HoverTool(tooltips="""
    <div>
        <div>
            <span style="font-size: 17px; font-weight: bold;">@desc</span>
        </div>
    </div>
    """
)

TOOLS = ['reset,box_zoom,wheel_zoom,zoom_in,zoom_out,pan', hover]
p = figure(plot_width=1000, plot_height=1000, tools=TOOLS, title="Dipeptides landscape")
p.circle('x', 'y', size=10, source=source, fill_alpha=0.8, line_alpha=0.8)

show(p, notebook_handle=True)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('desc', 749), ('x', 437), ('y', 437)
#   <div class="bk-root" id="05969886-e062-47c5-bb4e-079bd234b24a" data-root-id="1006"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[95]</strong>&gt;</code></p>

# %%
selected_peptides = ['FLAFVVFLL', 'QLFFSYFAV', 'ALWEIQQVV', 'FIAGLIAIV', 'LLFLMSFTV', 'ILHCANFNV',
 'NLSDRVVFV', 'FVLAAVYRI', 'AIFYLITPV', 'QMAPISAMV', 'FLALCADSI', 'LQLGFSTGV',
 'LLSAGIFGA', 'RQLLFVVEV', 'NVLAWLYAA', 'LVLSVNPYV', 'MLWCKDGHV', 'FLHVTYVPA',
 'LLDDFVEII', 'WLLWPVTLA', 'RIMASLVLA', 'FTISVTTEI', 'FLALITLAT', 'FIASFRLFA',
 'MLSDTLKNL', 'VLLAPLLSA', 'QLLFVVEVV', 'SIWNLDYII', 'IVDTVSALV', 'TLQPVSELL',
 'FLGIITTVA', 'YTVELGTEV', 'IQPGQTFSV', 'NLDYIINLI', 'GLVEVEKGV', 'LIVAAIVFI',
 'SVAALTNNV', 'LLAKDTTEA', 'PVYSFLPGV', 'MVYMPASWV', 'IVGVALLAV', 'TLKNTVCTV',
 'ALPETTADI', 'QLNRALTGI', 'FVCDNIKFA', 'SLRPDTRYV', 'ELLHAPATV', 'KVEGCMVQV',
 'ALAPNMMVT', 'ILGPLSAQT', 'SIDAFKLNI', 'VQEGVLTAV', 'NLREMLAHA', 'FCNDPFLGV',
 'HLKDGTCGL', 'GLLPPKNSI', 'KVFTTVDNI', 'IAIPTNFTI', 'VIGIVNNTV', 'GINASVVNI',
 'PLVDLPIGI', 'ILDGISQYS', 'TLATHGLAA', 'KLGSLVVRC', 'ALLEDEFTP', 'GLPGTILRT',
 'QQGEVPVSI', 'ELTPVVQTI']

# %%
solvent_exposure = []

for peptide in selected_peptides:
    print(peptide)

    structure = freesasa.Structure('data/rosetta_mhc/pdb/%s-ensemble.pdb' % peptide)
    result = freesasa.calc(structure)
    
    surface_contact = [result.residueAreas()['A']['%s' % i].relativeSideChain for i in range(181, 190)]
    solvent_exposure.append(surface_contact)

solvent_exposure = np.array(solvent_exposure)
solvent_exposure = np.nan_to_num(solvent_exposure, nan=0)
# Out:
# FLAFVVFLL
# QLFFSYFAV
# ALWEIQQVV
# FIAGLIAIV
# LLFLMSFTV
# ILHCANFNV
# NLSDRVVFV
# FVLAAVYRI
# AIFYLITPV
# QMAPISAMV
# FLALCADSI
# LQLGFSTGV
# LLSAGIFGA
# RQLLFVVEV
# NVLAWLYAA
# LVLSVNPYV
# MLWCKDGHV
# FLHVTYVPA
# LLDDFVEII
# WLLWPVTLA
# RIMASLVLA
# FTISVTTEI
# FLALITLAT
# FIASFRLFA
# MLSDTLKNL
# VLLAPLLSA
# QLLFVVEVV
# SIWNLDYII
# IVDTVSALV
# TLQPVSELL
# FLGIITTVA
# YTVELGTEV
# IQPGQTFSV
# NLDYIINLI
# GLVEVEKGV
# LIVAAIVFI
# SVAALTNNV
# LLAKDTTEA
# PVYSFLPGV
# MVYMPASWV
# IVGVALLAV
# TLKNTVCTV
# ALPETTADI
# QLNRALTGI
# FVCDNIKFA
# SLRPDTRYV
# ELLHAPATV
# KVEGCMVQV
# ALAPNMMVT
# ILGPLSAQT
# SIDAFKLNI
# VQEGVLTAV
# NLREMLAHA
# FCNDPFLGV
# HLKDGTCGL
# GLLPPKNSI
# KVFTTVDNI
# IAIPTNFTI
# VIGIVNNTV
# GINASVVNI
# PLVDLPIGI
# ILDGISQYS
# TLATHGLAA
# KLGSLVVRC
# ALLEDEFTP
# GLPGTILRT
# QQGEVPVSI
# ELTPVVQTI

# %%
np.mean(solvent_exposure, axis=0)
# Out:
# array([0.16150217, 0.00605522, 0.0733065 , 0.59842726, 0.3975365 ,
#        0.18371498, 0.27092293, 0.44505246, 0.00328194])

# %%
np.std(solvent_exposure, axis=0)
# Out:
# array([0.10301116, 0.00715641, 0.10967447, 0.26084893, 0.23788112,
#        0.20399901, 0.14212962, 0.18862531, 0.01176521])

# %%
ff = ForceField('mobius/data/parameters.csv')
ff._term_parameters['vdw']['score_max'] = 2
ff._term_parameters['vdw']['smooth'] = 0.1
ff._term_parameters['vdw']['n'] = 4
print(ff._term_parameters)

vt = VirtualTarget(ff)
# Out:
# {'vdw': {'epsilon': 1, 'smooth': 0.1, 'score_max': 2, 'n': 4, 'm': 3}}

# %%
target_sequence = selected_peptides[0]
vt.generate_pharmacophore_from_target_sequence(target_sequence, solvent_exposures=np.mean(solvent_exposure, axis=0))

# %%
terms = np.array([ff.score(vt.pharmacophore(), p, details=True)[1] for p in selected_peptides])

# %%
df[df['peptide'].isin(selected_peptides)].sort_values(by='binding_affinity')
# Out:
#        peptide  length  binding_affinity  energy template
# 90   FLAFVVFLL       9               6.7 -79.840     1EEZ
# 451  QLFFSYFAV       9               7.2 -76.455     1QSF
# 39   ALWEIQQVV       9               8.0 -69.007     3H7B
# 80   FIAGLIAIV       9               8.5 -75.254     3MRL
# 353  LLFLMSFTV       9               8.8 -75.196     1QRN
# ..         ...     ...               ...     ...      ...
# 284  KLGSLVVRC       9            1294.4 -63.007     1S9W
# 22   ALLEDEFTP       9            2049.4 -56.373     3FT4
# 184  GLPGTILRT       9            2343.9 -65.131     3FQT
# 462  QQGEVPVSI       9            2910.2 -50.869     4NNY
# 64   ELTPVVQTI       9            3101.6 -63.763     6PTB
#
# [68 rows x 5 columns]

# %%
binding_affinity = df[df['peptide'].isin(selected_peptides)].sort_values(by='binding_affinity')['binding_affinity']

# %%
scores = np.sum(terms[:,[0,1,2,3]], axis=1)
print(mean_squared_error(binding_affinity, scores))

fig, ax = plt.subplots(figsize=(10, 10))
sns.regplot(x=binding_affinity, y=scores, ax=ax)
plt.plot()
# Out:
# 648159.027093281
# []

# %%
def fun(x, binding_affinity, terms):
    scores = np.sum(np.prod((terms, x), axis=0), axis=1)
    return mean_squared_error(binding_affinity, scores)

bnds = ((1, 1000), (1, 1000), (1, 1000), (1, 1000))
res = optimize.minimize(fun, (1, 1, 1, 1), method='COBYLA', args=(binding_affinity, terms), bounds=bnds, tol=1e-10)
print('vdW: %f - Electrostatic: %f - HBond: %f - Desolvation: %f' % (res.x[0], res.x[1], res.x[2], res.x[3]))

fig, ax = plt.subplots(figsize=(10, 10))
sns.regplot(x=binding_affinity, y=np.sum(np.prod((terms, res.x), axis=0), axis=1), ax=ax)
plt.plot()
# Out:
# /home/eberhardt/Applications/miniconda3/envs/mm/lib/python3.9/site-packages/scipy/optimize/_minimize.py:544: RuntimeWarning: Method COBYLA cannot handle bounds.
#   warn('Method %s cannot handle bounds.' % method,
# vdW: 37.922778 - Electrostatic: 126.733389 - HBond: 55.189794 - Desolvation: -71.613657
# []

# %% [markdown]
# # Wan 2015 dataset

# %%
df = pd.read_csv('data/wan_2015/peptide_binding_affinity.csv')

# %%
ff = ForceField('mobius/data/parameters.csv')
ff._term_parameters['vdw']['score_max'] = 2
ff._term_parameters['vdw']['smooth'] = 0.1
ff._term_parameters['vdw']['n'] = 4
print(ff._term_parameters)

vt = VirtualTarget(ff)
# Out:
# {'vdw': {'epsilon': 1, 'smooth': 0.1, 'score_max': 2, 'n': 4, 'm': 3}}

# %%
target_sequence = 'FLIDLAFLI'
vt.generate_pharmacophore_from_target_sequence(target_sequence, solvent_exposures=np.mean(solvent_exposure, axis=0))

# %%
scores = vt.score_peptides(df['peptide'], noise=0)
terms = np.array([ff.score(vt.pharmacophore(), p, details=True)[1] for p in df['peptide']])

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.regplot(x=df['binding_affinity'], y=scores, ax=ax)
ax.plot()
# Out:
# []

# %%
def fun(x, binding_affinity, terms):
    scores = np.sum(np.prod((terms, x), axis=0), axis=1)
    return mean_squared_error(binding_affinity, scores)

bnds = ((1, 1000), (1, 1000), (1, 1000), (1, 1000))
res = optimize.minimize(fun, (1, 1, 1, 1), method='SLSQP', args=(df['binding_affinity'], terms), bounds=bnds, tol=1e-10)
print('vdW: %f - Electrostatic: %f - HBond: %f - Desolvation: %f' % (res.x[0], res.x[1], res.x[2], res.x[3]))

fig, ax = plt.subplots(figsize=(10, 10))
sns.regplot(x=df['binding_affinity'], y=np.sum(np.prod((terms, res.x), axis=0), axis=1), ax=ax)
plt.plot()
# Out:
# vdW: 496.561455 - Electrostatic: 999.999996 - HBond: 256.794366 - Desolvation: 999.999999
# []
